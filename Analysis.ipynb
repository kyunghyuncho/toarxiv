# %%
# %matplotlib notebook

import numpy
import matplotlib.pyplot as plot
import matplotlib

matplotlib.rcParams.update({'font.size': 22})
matplotlib.rcParams.update({'font.family': 'serif'})
# Out:
# /Users/kyunghyuncho/Library/Python/2.7/lib/python/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
data = numpy.loadtxt(open("./survey.csv","rb"),delimiter=",",skiprows=1,dtype=numpy.object)

# %%
answers = [numpy.unique(data[:, ii]) for ii in xrange(data.shape[1])]

# %%
portions = [len(numpy.where(data[:, 0] == aa)[0]) for aa in answers[0]]
portions = numpy.array(portions, dtype='float')/numpy.sum(portions)
print portions, answers[0]

f = plot.figure()
ax = f.gca()
ax.pie(portions, labels=['%2.1f%%'%(p*100) for p in portions])
plot.legend(['Not to arXiv', 'To arXiv'], loc='lower right')
plot.title('')
plot.show()
# Out:
# [ 0.33990148  0.66009852] ['No' 'Yes']
# <img src="data:image/png;base64,...">

# %%
portions = [len(numpy.where(data[:, 2] == aa)[0]) for aa in answers[2]]
portions = numpy.array(portions, dtype='float')/numpy.sum(portions)
print portions, answers[2]

f = plot.figure()
ax = f.gca()
ax.pie(portions, labels=['%2.1f%%'%(p*100) for p in portions])
plot.legend(answers[2], loc='best', fontsize=18, bbox_to_anchor=(0.7,0.1))
plot.title('')
plot.show()
# Out:
# [ 0.6453202  0.3546798] ['Machine Learning' 'Natural Language Processing']
# <img src="data:image/png;base64,...">

# %%
portions = [len(numpy.where(data[numpy.where(data[:,2]=='Machine Learning')[0], 0] == aa)[0]) 
            for aa in answers[0]]
portions = numpy.array(portions, dtype='float')/numpy.sum(portions)
print portions, answers[0]

f = plot.figure()
ax = f.gca()
ax.pie(portions, labels=['%2.1f%%'%(p*100) for p in portions])
plot.legend(['Not to arXiv', 'To arXiv'], loc='lower right')
plot.title('')
plot.show()
# Out:
# [ 0.24427481  0.75572519] ['No' 'Yes']
# <img src="data:image/png;base64,...">

# %%
portions = [len(numpy.where(data[numpy.where(data[:,2]==
                                             'Natural Language Processing')[0], 0] == aa)[0]) 
            for aa in answers[0]]
portions = numpy.array(portions, dtype='float')/numpy.sum(portions)
print portions, answers[0]

f = plot.figure()
ax = f.gca()
ax.pie(portions, labels=['%2.1f%%'%(p*100) for p in portions])
#plot.legend(['Not to arXiv', 'To arXiv'], loc='lower left')
plot.title('')
plot.show()
# Out:
# [ 0.51388889  0.48611111] ['No' 'Yes']
# <img src="data:image/png;base64,...">

# %%
portions = [len(numpy.where(data[:, 1] == aa)[0]) for aa in answers[1]]
portions = numpy.array(portions, dtype='float')/numpy.sum(portions)
print portions, answers[1]

f = plot.figure(figsize=(10,10))
ax = f.gca()
ax.pie(portions, labels=['%2.1f%%'%(p*100) for p in portions])
plot.legend(answers[1], loc='upper left', fontsize=12, bbox_to_anchor=(-0.1,0.4))
plot.title('')
plot.show()
# Out:
# [ 0.05418719  0.30049261  0.18719212  0.26108374  0.07881773  0.1182266 ] ['as soon as I receive reviews' 'as soon as I submit the manuscript'
#  'as soon as I write a manuscript (who cares about deadlines?)'
#  'as soon as the acceptance decision is made'
#  'during or after the conference' 'probably not']
# <img src="data:image/png;base64,...">

# %%
portions = [len(numpy.where(data[numpy.where(data[:,2]==
                                             'Machine Learning')[0], 1] == aa)[0]) 
            for aa in answers[1]]
portions = numpy.array(portions, dtype='float')/numpy.sum(portions)
print portions, answers[1]

f = plot.figure(figsize=(10,10))
ax = f.gca()
ax.pie(portions, labels=['%2.1f%%'%(p*100) for p in portions])
plot.legend(answers[1], loc='upper left', fontsize=12, bbox_to_anchor=(-0.1,0.8))
plot.title('')
plot.show()
# Out:
# [ 0.0610687   0.3740458   0.26717557  0.18320611  0.0610687   0.05343511] ['as soon as I receive reviews' 'as soon as I submit the manuscript'
#  'as soon as I write a manuscript (who cares about deadlines?)'
#  'as soon as the acceptance decision is made'
#  'during or after the conference' 'probably not']
# <img src="data:image/png;base64,...">

# %%
portions = [len(numpy.where(data[numpy.where(data[:,2]==
                                             'Natural Language Processing')[0], 1] == aa)[0]) 
            for aa in answers[1]]
portions = numpy.array(portions, dtype='float')/numpy.sum(portions)
print portions, answers[1]

f = plot.figure(figsize=(10,10))
ax = f.gca()
ax.pie(portions, labels=['%2.1f%%'%(p*100) for p in portions])
plot.legend(answers[1], loc='upper left', fontsize=12, bbox_to_anchor=(-0.1,0.4))
plot.title('')
plot.show()
# Out:
# [ 0.04166667  0.16666667  0.04166667  0.40277778  0.11111111  0.23611111] ['as soon as I receive reviews' 'as soon as I submit the manuscript'
#  'as soon as I write a manuscript (who cares about deadlines?)'
#  'as soon as the acceptance decision is made'
#  'during or after the conference' 'probably not']
# <img src="data:image/png;base64,...">
